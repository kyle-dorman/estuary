# %%
# %load_ext autoreload

from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv("../.env")
# Out:
# True

# %%
# %autoreload 2

from estuary.util.clustering import main

# %%
main()
# Out:
# site_type
# dynamic          65
# always_open       5
# always_closed     2
# Name: count, dtype: int64
# [angular] t=  0.3: n_clusters= 48  singletons= 40  max_size= 8
# [angular] t= 0.35: n_clusters= 35  singletons= 26  max_size=13
# [angular] t=  0.4: n_clusters= 27  singletons= 20  max_size=20
# [angular] t= 0.45: n_clusters= 19  singletons= 11  max_size=21
# [angular] t=  0.5: n_clusters= 10  singletons=  5  max_size=40
# cluster
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
# 6      3
# 7      1
# 8      2
# 9      6
# 10     6
# 11     1
# 12     1
# 13     3
# 14     2
# 15    11
# 16    21
# 17     1
# 18     1
# 19     1
# Name: count, dtype: int64
# Keeping 50 / 65
#         dynamic sites for plots (dropped singleton clusters)
# mean within-cluster corr:
#  1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6     0.689276
# 7          NaN
# 8     0.675348
# 9     0.760502
# 10    0.681229
# 11         NaN
# 12         NaN
# ...
